# %%
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.cider.cider import Cider

# 模拟：每张图像一个模型预测
hypothesis = {
    "1": ["a man riding a bike on the street"],
    "2": ["a group of people sitting around a table"],
    "3": ["a man riding a bike on the street"],
    "4": ["a group of people sitting around a table"],
    "5": ["a man riding a bike on the street"],
    "6": ["a group of people sitting around a table"],
    "7": ["a man riding a bike on the street"],
    "8": ["a group of people sitting around a table"]
}

# 每张图像多个 ground truth 参考句子
references = {
    "1": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "2": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ],
    "3": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "4": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ],
    "5": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "6": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ],
    "7": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "8": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ]
}

# BLEU (1-4)
bleu_scorer = Bleu(4)
bleu_score, _ = bleu_scorer.compute_score(references, hypothesis)

# CIDEr
cider_scorer = Cider()
cider_score, _ = cider_scorer.compute_score(references, hypothesis)

print("BLEU-4:", bleu_score[3])
print("CIDEr:", cider_score)
# Out:
# {'testlen': 64, 'reflen': 64, 'guess': [64, 56, 48, 40], 'correct': [56, 32, 4, 0]}
# ratio: 0.9999999999843749
# BLEU-4: 3.1947155211180975e-05
# CIDEr: 0.8471879625484504

# %%
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.cider.cider import Cider

# 模拟：每张图像一个模型预测
hypothesis = {
    "1": ["a man riding a bike on the street"],
    "2": ["a group of people sitting around a table"],
    "3": ["a man riding a bike on the street"],
    "4": ["a group of people sitting around a table"]
}

# 每张图像多个 ground truth 参考句子
references = {
    "1": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "2": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ],
    "3": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "4": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ]
}

# BLEU (1-4)
bleu_scorer = Bleu(4)
bleu_score, _ = bleu_scorer.compute_score(references, hypothesis)

# CIDEr
cider_scorer = Cider()
cider_score, _ = cider_scorer.compute_score(references, hypothesis)

print("BLEU-4:", bleu_score[3])
print("CIDEr:", cider_score)
# Out:
# {'testlen': 32, 'reflen': 32, 'guess': [32, 28, 24, 20], 'correct': [28, 16, 2, 0]}
# ratio: 0.9999999999687501
# BLEU-4: 3.799178427988572e-05
# CIDEr: 0.9732394887524672

# %%
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.cider.cider import Cider

# 模拟：每张图像一个模型预测
hypothesis = {
    "1": ["a man riding a bike on the street"],
    "2": ["a group of people sitting around a table"]
}

# 每张图像多个 ground truth 参考句子
references = {
    "1": [
        "a person is riding a bicycle on a road",
        "a man rides a bike through a city street",
        "a man on a bicycle",
        "someone is cycling on the street",
        "a man is biking downtown"
    ],
    "2": [
        "people are eating together at a table",
        "a group is having a meal",
        "several individuals sit at a dining table",
        "people sitting and sharing food",
        "dinner time with friends"
    ]
}

# BLEU (1-4)
bleu_scorer = Bleu(4)
bleu_score, _ = bleu_scorer.compute_score(references, hypothesis)

# CIDEr
cider_scorer = Cider()
cider_score, _ = cider_scorer.compute_score(references, hypothesis)

print("BLEU-4:", bleu_score[3])
print("CIDEr:", cider_score)
# Out:
# {'testlen': 16, 'reflen': 16, 'guess': [16, 14, 12, 10], 'correct': [14, 8, 1, 0]}
# ratio: 0.9999999999375
# BLEU-4: 4.518010017408502e-05
# CIDEr: 1.1885793426334594
